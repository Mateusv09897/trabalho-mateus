# %% [markdown]
# # Práticas em Python
# Variáveis e Objetos

# %%
#Cria variável do tipo inteiro
x = 6
print(x)
#Cria variável do tipo float
y = 9.8
print(y)
#Cria variável do tipo string
m = "Mateus"
m = 'Mateus'
print(m)
#Cria variável do tipo lógica
w = False
y = True
print(y)
# Out:
# 6
# 9.8
# Mateus
# True

# %%
#calculadora
x = 200
y = 2
z = 10
w = (x + y) * z / 100
print(w)
# Out:
# 20.2

# %%
print("Vamos estudar!")
# Out:
# Vamos estudar!

# %%
#exibir texto no console
print("Este texto será impresso no console")
print(x)
print("Texto e duas variáveis: ", x ,", ", z)
# Out:
# Este texto será impresso no console
# 200
# Texto e duas variáveis:  200 ,  10

# %%
#verificar tipo
print(type(x))
print(type(m))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#entrada de dados
print("Informe o valor: ")
i = input()
#mostra tipo string
print(type(i))
# Out:
# Informe o valor:

# %%
#entrada de valor com msg separada e junto
print("Informe o valor: ")
i = input()
# ou
i = input("Informe o valor: ")

# %%
#conversão de valores
#para inteiro
var = input("Informe o valor: ")
print(type(var))
var = int(var)
print(type(var))

# %%
#para float
var = input("Informe o valor: ")
print(type(var))
var = float(var)
print(type(var))

# %%
# Este texto é um comentário
X = 100  # a partir daqui é um comentário
